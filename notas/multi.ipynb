# %% [markdown]
# ## Multithreading (Multi hilos) & Multiprocessing (Multi procesos)

# %% [markdown]
# ### Test unitario:
#
# Un test unitario en Python es una prueba automatizada que verifica si una parte específica de tu código (normalmente una función o un método) funciona correctamente. Se les llama "unitarios" porque prueban unidades pequeñas de código de manera aislada.
